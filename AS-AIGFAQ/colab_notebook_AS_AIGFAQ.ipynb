# %% [markdown]
# <a href="https://colab.research.google.com/github/AS-AIGFAQ/AS-AIGFAQ/blob/main/colab_notebook_AS_AIGFAQ.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # AI Generated FAQ by Academia Sinica (AS-AIGFAQ)
#
# ## 現有行政服務的常態與問題
#
# - 所有的法條、服務說明、公告事項都會放置在網站上
# - 網頁就像一個大迷宮，什麼都有，但是想找的往往都找不到
# - 最快的方法就是打電話問承辦人，導致承辦人花費大量的時間在回答類似的問題，反而減少可以處理日常公務的時間
#
# ## 現有行政服務的解方
#
# - 單一服務窗口：由專業客服代為回答簡易問題。但是，複雜問題仍須轉介承辦人、轉介案的回應所需時間拉長、客服可能判斷錯誤
# - 整理 FAQ 讓使用者自行查詢：由專人撰寫且隨時更新 FAQ。但是，FAQ 的文句、口氣、題目類型難以標準化；更新時容易掛一漏萬
# - 導入 chatbot ：根據資料庫設計交談式機器人回答問題。但是，往往只能回答制式問題、需花費大量成本進行調校
#
# ## 我們的解法
#
# - 讓 chatGPT 提供對使用者感興趣的問題建議，進而達到自動生成 FAQ 的目標
# - 透過 OpenAI API，施展咒語 (prompt) 讓 chatGPT  依據輸入的內容 (context，即相關規定) 提出問題；接著再請 chatGPT  依據輸入的內容，回答所收集到的問題
#
#
# ## 註記
#
# 以下程式內容說明與註解，皆由 ChatGPT 產生，並經人工簡略編輯而成。

# %% [markdown]
# ## Initialization

# %% [markdown]
# 首先我們升級 pip 和 openai 套件的版本，並且設定為在靜默模式下執行，以避免顯示太多的輸出。
#
# First, we upgrade the versions of the pip and openai packages in quiet mode to avoid displaying too much output.

# %%
# Upgrade pip (Python package installer) to the latest version in quiet mode
# !pip install -q --upgrade pip

# Install or upgrade the 'openai' package in quiet mode
# !pip install -q --upgrade openai

# %% [markdown]
# 接著導入 openai 和 pandas 庫，然後設置了環境變量 OPENAI_API_KEY 的值。接著並將 openai.api_key 設為 API 密鑰。最後，設置了文件名和 HTML 標題。
#
# We import the openai and pandas libraries, then sets the value of the environment variable OPENAI_API_KEY. After that, it sets openai.api_key to the API key. Finally, it sets the file name and HTML title.

# %%
import openai
import pandas as pd

# Set the environment variable for OpenAI API key
# %env OPENAI_API_KEY=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

# Set organization and API key for OpenAI
openai.organization = ""
openai.api_key = "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"

# Set the file name and HTML title
fname = 'AS-ITS'
HTML_title = '中央研究院 資訊服務 FAQ'

faq_name = fname + '-QA.csv'
# Out:
# env: OPENAI_API_KEY=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

# %% [markdown]
# # Read in the data

# %% [markdown]
# 我們首先從 csv 檔案中讀取資料並將其存入名為 df 的變數。然後，我們印出原始資料的行數。接著，我們使用 dropna 函數移除 df 中所有空行，並用 inplace 參數直接替換原資料。最後，我們印出移除空行後的行數，並顯示前五行資料。
#
# We first read data from a csv file and store it in a variable called df. Then, we print the number of rows in the original data. After that, we use the dropna function to remove all empty rows in df, and replace the original data directly with the inplace parameter. Finally, we print the number of rows after removing empty rows and display the first five rows of data.

# %%
# Read data from a csv file and store it in the 'df' variable
df = pd.read_csv(fname + ".csv")

# Print the number of rows in the original data
print("Before removing empty rows: " + str(len(df.index)))

# Remove all empty rows in 'df' and replace the original data directly with the inplace parameter
df.dropna(inplace = True)   

# Print the number of rows after removing empty rows
print("After removing empty rows: " + str(len(df.index)))

# Display the first five rows of data
df.head()
# Out:
# Before removing empty rows: 71
# After removing empty rows: 70
#       category             title  \
# 0    資訊服務處相關服務         資訊服務處相關服務
# 1       全院共用服務            全院共用服務
# 2  全院共用服務-綜合業務  員工帳號(SSO)申請與密碼設定
# 3  全院共用服務-綜合業務            單一服務窗口
# 4  全院共用服務-綜合業務          資訊課程推廣說明
#
#                                              context group  \
# 0  中研院資訊服務處主要任務為「支援中研院各單位之研究工作及行政業務電腦化」，身為中研院唯一的資...    資訊
# 1  中研院資訊服務處提供之全院共用服務，共有綜合業務、網路資訊和圖書資訊三大類，全院共用服務多使...    資訊
# 2  中研院員工帳號與密碼用來存取本院各項訊服務，例如Webmail、MySpace、AS_Sec...    資訊
# 3  資訊服務處提供專人諮詢服務，中研院資訊相關服務問題都能諮詢，協助同仁在最短的時間內解決各項問...    資訊
# 4  中研院資訊推廣課程適用對象為院內在職同仁且具備SSO帳號者皆可參加。資訊推廣課程包含各種資訊...    資訊
#
#                                       url                contact
# 0  https://its.sinica.edu.tw/posts/117049  資訊服務處服務台 02-2789-8855
# 1               https://its.sinica.edu.tw  資訊服務處服務台 02-2789-8855
# 2    https://its.sinica.edu.tw/pages/3256  資訊服務處服務台 02-2789-8855
# 3    https://its.sinica.edu.tw/pages/1672  資訊服務處服務台 02-2789-8855
# 4    https://its.sinica.edu.tw/pages/1673  資訊服務處服務台 02-2789-8855

# %% [markdown]
# # Use OpenAI API (gpt-3.5-turbo) to generate Q&A

# %% [markdown]
# ## Create questions based on the data

# %% [markdown]
# 我們定義了一個名為 chatGPT_get_questions 的函數，它接收一個名為 row 的參數。函數中，我們嘗試建立一個問題 q，根據服務項目和服務說明來提出問題。然後，我們使用 GPT-3.5 Turbo 模型向 OpenAI 請求回答。如果一切正常，我們將返回回答內容。如果遇到錯誤，則返回空字符串。
#
# We define a function called chatGPT_get_questions, which takes a parameter called row. In the function, we try to create a question q based on the service item and service description. Then, we request an answer from OpenAI using the GPT-3.5 Turbo model. If everything goes well, we return the answer content. If there is an error, we return an empty string.

# %%
def chatGPT_get_questions(row):
    try:
        # Create a question based on the service item and service description
        q = "請根據以下的服務項目與服務說明，提出以問號為結尾，並且清楚說明服務項目的問題\n\n服務項目：{"+row.title+"}\n\n服務說明：{"+row.context+"}\n\n問題：\n1."
        
        # Request an answer from OpenAI using the GPT-3.5 Turbo model
        rsp = openai.ChatCompletion.create(
            model="gpt-3.5-turbo",
            messages=[
                {"role": "system", "content": "使用者"},
                {"role": "user", "content": q}
            ]
        )
        
        # Return the answer content
        return rsp.get("choices")[0]["message"]["content"]
    except:
        # Return an empty string if there is an error
        return ""

# %% [markdown]
# 我們首先使用 apply 函數將 chatGPT_get_questions 函數應用到 df 的每一行，並將結果存儲在名為 questions 的新列中。接著，我們在每個 questions 列的開頭加上 "1."。最後，我們印出 df 中第一行的 questions 列的值。
#
# We first use the apply function to apply the chatGPT_get_questions function to each row of df and store the result in a new column called questions. Then, we add "1." to the beginning of each questions column. Finally, we print the value of the questions column in the first row of df.

# %%
# Apply the 'chatGPT_get_questions' function to each row of 'df' and store the result in a new column called 'questions'
df['questions'] = df.apply(chatGPT_get_questions, axis=1)

# Add "1." to the beginning of each 'questions' column
df['questions'] = "1." + df.questions

# Print the value of the 'questions' column in the first row of 'df'
print(df[['questions']].values[0][0])
# Out:
# 1.請問資訊服務處的主要任務是什麼？

# %% [markdown]
# 我們在這裡分別使用 head () 和 tail () 函數來查看 df 的前五行和後五行資料。
#
# Here, we use the head() and tail() functions to view the first five rows and last five rows of df, respectively.

# %%
# Display the first five rows of 'df'
df.head()

# Display the last five rows of 'df'
df.tail()
# Out:
#        category     title                                            context  \
# 66  全院共用服務-綜合業務  電腦教室使用說明  資訊服務處管理之電腦教室共有2間，分別為資訊服務處所屬生技園區生物資訊中心電腦教室及資訊服務...
# 67  全院共用服務-綜合業務    授權軟體列表  中央研究院聯合採購之授權軟體項目、各軟體下載及使用說明，可至https://its.sini...
# 68  全院共用服務-綜合業務      重要記事  資訊服務處各年度重要記事，請至https://its.sinica.edu.tw/pages...
# 69  全院共用服務-綜合業務      重要措施  資訊服務處自109年度起，每半年發布重要措施資訊，文件中會將資訊服務處近半年將推出的新服務或...
# 70  全院共用服務-綜合業務    服務申請表單  資訊服務處各項服務紙本申請表，包含宿舍網路申請、大量訊息傳遞申請表...等等，請至https...
#
#    group                                     url                contact  \
# 66    資訊  https://its.sinica.edu.tw/posts/165678  資訊服務處服務台 02-2789-8873
# 67    資訊    https://its.sinica.edu.tw/pages/1732  資訊服務處服務台 02-2789-8874
# 68    資訊    https://its.sinica.edu.tw/pages/1664  資訊服務處服務台 02-2789-8875
# 69    資訊    https://its.sinica.edu.tw/pages/3124  資訊服務處服務台 02-2789-8876
# 70    資訊    https://its.sinica.edu.tw/pages/1724  資訊服務處服務台 02-2789-8877
#
#                                             questions
# 66  1.生物資訊中心電腦教室的借用申請流程是什麼？\n2. 人文館遠距會議室電腦教室的借用申請流...
# 67  1.請問中央研究院授權軟體列表包含哪些軟體？\n2. 中央研究院授權軟體項目有哪些授權軟體可...
# 68  1.請問重要記事的內容是哪些？\n2. 請問如何瀏覽重要事項的相關資訊？\n3. 重要記事的...
# 69                                                 1.
# 70      1.服務申請表單是否需要填寫特定的基本資料？\n2. 服務申請表單是否只提供紙本申請方式？

# %% [markdown]
# 我們導入 re（正則表達式）模組。然後，創建一個新的空 DataFrame，命名為 df2，包含四個列：'category'、'title'、'context' 和 'question'。接著，我們遍歷 df 中的每一行，將每一行的 'questions' 列拆分成多個問題。對於每個問題，我們移除問題序號（例如 "1."），並創建一個新的 DataFrame（new_df）包含當前問題及其相應的 'category'、'title' 和 'context'。最後，我們將 new_df 添加到 df2 中，並更新問題序號 i。
#
# We import the re (regular expression) module. Then, we create a new empty DataFrame called df2, containing four columns: 'category', 'title', 'context', and 'question'. Next, we iterate through each row in df, splitting the 'questions' column in each row into multiple questions. For each question, we remove the question number (e.g., "1.") and create a new DataFrame (new_df) containing the current question and its corresponding 'category', 'title', and 'context'. Finally, we add new_df to df2 and update the question number i.

# %%
import re

# Create a new empty DataFrame called 'df2' with four columns
df2 = pd.DataFrame(columns=['category', 'title', 'context', 'question'])

# Iterate through each row in 'df'
for index, row in df.iterrows():
    # Split the 'questions' column in each row into multiple questions
    questions = row['questions'].split("\n")
    i = 1
    for q in questions:
        if len(q) != 0:
            # Remove the question number (e.g., "1.") and strip leading whitespace
            q = re.sub("\d.", "", q, count=1).lstrip()
            
            # Create a new DataFrame containing the current question and its corresponding 'category', 'title', and 'context'
            new_df = pd.DataFrame(data={'category': [row['category']], 'title': [row['title']], 'context': [row['context']], 'question': [q]})
            
            # Add 'new_df' to 'df2'
            df2 = pd.concat([df2, new_df], axis=0, ignore_index=True)
            
            # Update the question number
            i = i + 1

# %% [markdown]
# 在這裡，我們顯示整個 df2 DataFrame。根據之前的程式碼，df2 包含從原始 df DataFrame 生成的處理過的問題，每個問題與相應的 'category'、'title' 和 'context' 存儲在單獨的行中。
#
# Here, we display the entire df2 DataFrame. Based on the previous code, df2 contains the processed questions generated from the original df DataFrame, with each question and its corresponding 'category', 'title', and 'context' stored in separate rows.

# %%
# Display the entire 'df2' DataFrame
df2
# Out:
#         category             title  \
# 0      資訊服務處相關服務         資訊服務處相關服務
# 1         全院共用服務            全院共用服務
# 2         全院共用服務            全院共用服務
# 3         全院共用服務            全院共用服務
# 4    全院共用服務-綜合業務  員工帳號(SSO)申請與密碼設定
# ..           ...               ...
# 339  全院共用服務-綜合業務              重要記事
# 340  全院共用服務-綜合業務              重要記事
# 341  全院共用服務-綜合業務              重要措施
# 342  全院共用服務-綜合業務            服務申請表單
# 343  全院共用服務-綜合業務            服務申請表單
#
#                                                context  \
# 0    中研院資訊服務處主要任務為「支援中研院各單位之研究工作及行政業務電腦化」，身為中研院唯一的資...
# 1    中研院資訊服務處提供之全院共用服務，共有綜合業務、網路資訊和圖書資訊三大類，全院共用服務多使...
# 2    中研院資訊服務處提供之全院共用服務，共有綜合業務、網路資訊和圖書資訊三大類，全院共用服務多使...
# 3    中研院資訊服務處提供之全院共用服務，共有綜合業務、網路資訊和圖書資訊三大類，全院共用服務多使...
# 4    中研院員工帳號與密碼用來存取本院各項訊服務，例如Webmail、MySpace、AS_Sec...
# ..                                                 ...
# 339  資訊服務處各年度重要記事，請至https://its.sinica.edu.tw/pages...
# 340  資訊服務處各年度重要記事，請至https://its.sinica.edu.tw/pages...
# 341  資訊服務處自109年度起，每半年發布重要措施資訊，文件中會將資訊服務處近半年將推出的新服務或...
# 342  資訊服務處各項服務紙本申請表，包含宿舍網路申請、大量訊息傳遞申請表...等等，請至https...
# 343  資訊服務處各項服務紙本申請表，包含宿舍網路申請、大量訊息傳遞申請表...等等，請至https...
#
#                         question
# 0               請問資訊服務處的主要任務是什麼？
# 1          全院共用服務中的綜合業務具體是指什麼項目？
# 2             全院共用服務的網路資訊包含哪些內容？
# 3    全院共用服務中的圖書資訊是指提供員工借閱圖書的服務嗎？
# 4               申請中研院員工帳號的方式是什麼？
# ..                           ...
# 339                 重要事項資訊是公開的嗎？
# 340         除了瀏覽相關資訊外，還有其他服務提供嗎？
# 341
# 342         服務申請表單是否需要填寫特定的基本資料？
# 343           服務申請表單是否只提供紙本申請方式？
#
# [344 rows x 4 columns]

# %% [markdown]
# ## Create answers based on the context

# %% [markdown]
# 我們在這裡定義了一個名為 chatGPT_get_answers 的函數，它接收一個名為 row 的參數。函數中，我們嘗試建立一個問題 q，根據文字說明來回答問題。然後，我們使用 GPT-3.5 Turbo 模型向 OpenAI 請求回答。如果一切正常，我們將返回去除左右空格後的答案內容。如果遇到錯誤，則返回空字符串。
#
# We define a function called chatGPT_get_answers, which takes a parameter called row. In the function, we try to create a question q based on the text description to answer the question. Then, we request an answer from OpenAI using the GPT-3.5 Turbo model. If everything goes well, we return the answer content with leading and trailing whitespaces removed. If there is an error, we return an empty string.

# %%
def chatGPT_get_answers(row):
    try:
        # Create a question based on the text description to answer the question
        q = "請根據下列的文字說明來回答問題\n\n文字說明： {"+row.context+"}\n\n問題：\n{"+row.question+"}\n\n答案："
        
        # Request an answer from OpenAI using the GPT-3.5 Turbo model
        rsp = openai.ChatCompletion.create(
            model="gpt-3.5-turbo-0301",
            messages=[
                {"role": "system", "content": "中研院"},
                {"role": "user", "content": q}
            ]
        )
        
        # Return the answer content with leading and trailing whitespaces removed
        return rsp.get("choices")[0]["message"]["content"].lstrip().rstrip()
    except:
        # Return an empty string if there is an error
        return ""

# %% [markdown]
# 在下面這段程式碼中，我們首先使用 apply 函數將 chatGPT_get_answers 函數應用到 df2 的每一行，並將結果存儲在名為 answer 的新列中。接著，我們移除 answer 列中的左右空格。然後，我們從 df2 中移除空值，重新設置索引，刪除索引列。最後，我們印出 df2 中第一行的 answer 列的值。
#
# In the following code snippet, we first use the apply function to apply the chatGPT_get_answers function to each row of df2 and store the result in a new column called answer. Then, we remove leading and trailing whitespaces from the answer column. Next, we remove null values from df2, reset the index, and drop the index column. Finally, we print the value of the answer column in the first row of df2.

# %%
# Apply the 'chatGPT_get_answers' function to each row of 'df2' and store the result in a new column called 'answer'
df2['answer'] = df2.apply(chatGPT_get_answers, axis=1)

# Remove leading and trailing whitespaces from the 'answer' column
df2['answer'] = df2.answer

# Remove null values from 'df2', reset the index, and drop the index column
df2 = df2.dropna().reset_index().drop('index', axis=1)

# Print the value of the 'answer' column in the first row of 'df2'
print(df2[['answer']].values[0][0])
# Out:
# 資訊服務處主要任務為「支援中研院各單位之研究工作及行政業務電腦化」。

# %% [markdown]
# ## Save Q/A to a CSV file

# %% [markdown]
# 將 df2 DataFrame 寫入名為 faq_name 的 CSV 文件中，不包含索引列。
#
# This line of code writes the df2 DataFrame to a CSV file named faq_name, without including the index column.

# %%
# Write the 'df2' DataFrame to a CSV file named 'faq_name', without including the index column
df2.to_csv(faq_name, index=False)

# %% [markdown]
# # Generate FAQ Pages

# %% [markdown]
# ## Read QA csv file

# %% [markdown]
# 在這段程式碼中，我們首先使用 read_csv 函數讀取名為 faq_name 的 CSV 文件，並將其存儲在一個名為 df 的 DataFrame 中。接著，我們印出 df 中的行數。然後，我們使用 dropna 函數移除 df 中的空行。最後，我們印出 df 的前五行。
#
# In this code snippet, we first use the read_csv function to read the CSV file named faq_name and store it in a DataFrame called df. Then, we print the number of rows in df. Next, we use the dropna function to remove empty rows from df. Finally, we print the first five rows of df.

# %%
# Read the CSV file named 'faq_name' and store it in a DataFrame called 'df'
df = pd.read_csv(faq_name)

# Print the number of rows in 'df'
print("Before removing empty rows: " + str(len(df.index)))

# Remove empty rows from 'df'
df.dropna(inplace=True)

# Print the number of rows in 'df' after removing empty rows
print("After removing empty rows: " + str(len(df.index)))

# Print the first five rows of 'df'
df.head()
# Out:
# Before removing empty rows: 344
# After removing empty rows: 342
#       category             title  \
# 0    資訊服務處相關服務         資訊服務處相關服務
# 1       全院共用服務            全院共用服務
# 2       全院共用服務            全院共用服務
# 3       全院共用服務            全院共用服務
# 4  全院共用服務-綜合業務  員工帳號(SSO)申請與密碼設定
#
#                                              context  \
# 0  中研院資訊服務處主要任務為「支援中研院各單位之研究工作及行政業務電腦化」，身為中研院唯一的資...
# 1  中研院資訊服務處提供之全院共用服務，共有綜合業務、網路資訊和圖書資訊三大類，全院共用服務多使...
# 2  中研院資訊服務處提供之全院共用服務，共有綜合業務、網路資訊和圖書資訊三大類，全院共用服務多使...
# 3  中研院資訊服務處提供之全院共用服務，共有綜合業務、網路資訊和圖書資訊三大類，全院共用服務多使...
# 4  中研院員工帳號與密碼用來存取本院各項訊服務，例如Webmail、MySpace、AS_Sec...
#
#                       question  \
# 0             請問資訊服務處的主要任務是什麼？
# 1        全院共用服務中的綜合業務具體是指什麼項目？
# 2           全院共用服務的網路資訊包含哪些內容？
# 3  全院共用服務中的圖書資訊是指提供員工借閱圖書的服務嗎？
# 4             申請中研院員工帳號的方式是什麼？
#
#                                               answer
# 0                 資訊服務處主要任務為「支援中研院各單位之研究工作及行政業務電腦化」。
# 1  文字說明中沒有具體說明綜合業務指的是哪些項目，需要參考中研院資訊服務處網頁https://i...
# 2  無法確定。提供的文字說明中只提到全院共用服務包含綜合業務、網路資訊和圖書資訊三大類，但沒有列...
# 3  無法確定。文中只提到全院共用服務中有圖書資訊，但沒有具體說明是提供員工借閱圖書的服務或其他相...
# 4  申請中研院員工帳號的方式是至「院內行政服務」系統( https://ssoz.apps.si...

# %% [markdown]
# ## Convert to HTML files

# %% [markdown]
# 在這段程式碼中，我們首先使用 iterrows 函數遍歷 df 中的每一行，如果類別不在 FAQ 中，則添加一個新的類別。接著，我們將每個問題和答案添加到相應的類別中。然後，我們使用 HTML 和 CSS 創建一個基本的網頁模板，將 FAQ 呈現為摺疊式的結構，並將其寫入名為 faq_name.html 的文件中。
#
# In this code snippet, we first use the iterrows function to iterate through each row of df. If the category is not in FAQ, we add a new category. Then, we add each question and answer to the corresponding category. Next, we use HTML and CSS to create a basic webpage template that presents the FAQ as a collapsible structure and write it to a file named faq_name.html.

# %%
FAQ = {}
for index, row in df.iterrows():
  if row.category not in FAQ:
    FAQ[row.category] = {}
  FAQ[row.category][ "[" + row.title + "] " + row.question] = row.answer

# %%
html = "&lt;html>&lt;head>"

html += "&lt;meta charset=\"utf-8\">"
html += "&lt;script src=\"https://cdnjs.cloudflare.com/ajax/libs/jquery/3.2.1/jquery.min.js\">&lt;/script>"
html += "&lt;link rel=\"stylesheet\" href=\"https://maxcdn.bootstrapcdn.com/bootstrap/4.0.0/css/bootstrap.min.css\">"
html += "&lt;link rel=\"stylesheet\" href=\"FAQ.css\">"
html += "&lt;script src=\"https://stackpath.bootstrapcdn.com/bootstrap/4.0.0/js/bootstrap.bundle.min.js\">&lt;/script>"

html += "&lt;/head>&lt;body>"

html += "&lt;div class=\"container\">"
html += "&lt;center>&lt;h1>" + HTML_title + "&lt;/h1>&lt;p>&lt;/center>"

html += "&lt;div class=\"accordion_one\">&lt;div id=\"accordion\">"
num = 1
for category in FAQ:
  html += '&lt;div class="card">'
  if num==1:
    html += '&lt;div class="card-header" id="heading-'+str(num)+'">&lt;h5 class="mb-0">&lt;button class="btn btn-link" data-toggle="collapse" data-target="#collapse-'+str(num)+'" aria-expanded="true" aria-controls="collapse-'+str(num)+'">'
  else:
    html += '&lt;div class="card-header" id="heading-'+str(num)+'">&lt;h5 class="mb-0">&lt;button class="btn btn-link collapsed" data-toggle="collapse" data-target="#collapse-'+str(num)+'" aria-expanded="false" aria-controls="collapse-'+str(num)+'">'
  html += "&lt;h2>" + category + "&lt;/h2>"
  html += '&lt;/button>&lt;/h5>'
  html += '&lt;/div>'
  if num==1:
    html += '&lt;div id="collapse-'+str(num)+'" class="collapse show" aria-labelledby="heading-'+str(num)+'" data-parent="#accordion">'
  else:
    html += '&lt;div id="collapse-'+str(num)+'" class="collapse" aria-labelledby="heading-'+str(num)+'" data-parent="#accordion">'   
  html += '&lt;div class="card-body">'

  html += '&lt;div class="panel-group" id="accordionFourLeft">'
  for question in FAQ[category]:
    html += '&lt;div class="panel panel-default">&lt;div class="panel-heading">&lt;h4 class="panel-title">&lt;a data-toggle="collapse" data-parent="#accordion_oneLeft" href="#collapseFiveLeft-'+str(num)+'" aria-expanded="false" class="collapsed">'
    html += question
    html += '&lt;/a>&lt;/h4>&lt;/div>&lt;div id="collapseFiveLeft-'+str(num)+'" class="panel-collapse collapse" aria-expanded="false" role="tablist" style="height: 0px;">&lt;div class="panel-body">&lt;div class="text-accordion">&lt;p>'
    html += FAQ[category][question]
    html += '&lt;/p>&lt;/div>&lt;/div>&lt;/div>&lt;/div>'
    num = num + 1
  html += '&lt;/div>'

  html += '&lt;/div>&lt;/div>&lt;/div>'
html += '&lt;/div>&lt;/div>'
html += '&lt;/div>'
html += '&lt;/body>&lt;/html>'
print(html)

with open(faq_name + '.html', 'w') as writefile:
    writefile.write(html)
    writefile.close()
# Out:
# &lt;html>&lt;head>&lt;meta charset="utf-8">&lt;script src="https://cdnjs.cloudflare.com/ajax/libs/jquery/3.2.1/jquery.min.js">&lt;/script>&lt;link rel="stylesheet" href="https://maxcdn.bootstrapcdn.com/bootstrap/4.0.0/css/bootstrap.min.css">&lt;link rel="stylesheet" href="FAQ.css">&lt;script src="https://stackpath.bootstrapcdn.com/bootstrap/4.0.0/js/bootstrap.bundle.min.js">&lt;/script>&lt;/head>&lt;body>&lt;div class="container">&lt;center>&lt;h1>中央研究院 資訊服務 FAQ&lt;/h1>&lt;p>&lt;/center>&lt;div class="accordion_one">&lt;div id="accordion">&lt;div class="card">&lt;div class="card-header" id="heading-1">&lt;h5 class="mb-0">&lt;button class="btn btn-link" data-toggle="collapse" data-target="#collapse-1" aria-expanded="true" aria-controls="collapse-1">&lt;h2>資訊服務處相關服務&lt;/h2>&lt;/button>&lt;/h5>&lt;/div>&lt;div id="collapse-1" class="collapse show" aria-labelledby="heading-1" data-parent="#accordion">&lt;div class="card-body">&lt;div class="panel-group" id="accordionFourLeft">&lt;div class="panel panel-default">&lt;div class="panel-heading">&lt;h4 class="panel-title">&lt;a data-toggle="collapse" data-parent="#accordion_oneLeft" href="#collapseFiveLeft-1" aria-expanded="false" class="collapsed">[資訊服務處相關服務] 請問資訊服務處的主要任務是什麼？&lt;/a>&lt;/h4>&lt;/div>&lt;div id="collapseFiveLeft-1" class="panel-collapse collapse" aria-expanded="false" role="tablist" style="height: 0px;">&lt;div class="panel-body">&lt;div class="text-accordion">&lt;p>資訊服務處主要任務為「支援中研院各單位之研究工作及行政業務電腦化」。&lt;/p>&lt;/div>&lt;/div>&lt;/div>&lt;/div>&lt;/div>&lt;/div>&lt;/div>&lt;/div>&lt;div class="card">&lt;div class="card-header" id="heading-2">&lt;h5 class="mb-0">&lt;button class="btn btn-link collapsed" data-toggle="collapse" data-target="#collapse-2" aria-expanded="false" aria-controls="collapse-2">&lt;h2>全院共用服務&lt;/h2>&lt;/button>&lt;/h5>&lt;/div>&lt;div id="collapse-2" class="collapse" aria-labelledby="heading-2" data-parent="#accordion">&lt;div class="card-body">&lt;div class="panel-group" id="accordionFourLeft">&lt;div class="panel panel-default">&lt;div class="panel-heading">&lt;h4 class="panel-title">&lt;a data-toggle="collapse" data-parent="#accordion_oneLeft" href="#collapseFiveLeft-2" aria-expanded="false" class="collapsed">[全院共用服務] 全院共用服務中的綜合業務具體是指什麼項目？&lt;/a>&lt;/h4>&lt;/div>&lt;div id="collapseFiveLeft-2" class="panel-collapse collapse" aria-expanded="false" role="tablist" style="height: 0px;">&lt;div class="panel-body">&lt;div class="text-accordion">&lt;p>文字說明中沒有具體說明綜合業務指的是哪些項目，需要參考中研院資訊服務處網頁https://its.sinica.edu.tw 了解詳細資訊。&lt;/p>&lt;/div>&lt;/div>&lt;/div>&lt;/div>&lt;div class="panel panel-default">&lt;div class="panel-heading">&lt;h4 class="panel-title">&lt;a data-toggle="collapse" data-parent="#accordion_oneLeft" href="#collapseFiveLeft-3" aria-expanded="false" class="collapsed">[全院共用服務] 全院共用服務的網路資訊包含哪些內容？&lt;/a>&lt;/h4>&lt;/div>&lt;div id="collapseFiveLeft-3" class="panel-collapse collapse" aria-expanded="false" role="tablist" style="height: 0px;">&lt;div class="panel-body">&lt;div class="text-accordion">&lt;p>無法確定。提供的文字說明中只提到全院共用服務包含綜合業務、網路資訊和圖書資訊三大類，但沒有列出網路資訊的具體內容。建議參考中研院資訊服務處的網頁了解詳細的內容。&lt;/p>&lt;/div>&lt;/div>&lt;/div>&lt;/div>&lt;div class="panel panel-default">&lt;div class="panel-heading">&lt;h4 class="panel-title">&lt;a data-toggle="collapse" data-parent="#accordion_oneLeft" href="#collapseFiveLeft-4" aria-expanded="false" class="collapsed">[全院共用服務] 全院共用服務中的圖書資訊是指提供員工借閱圖書的服務嗎？&lt;/a>&lt;/h4>&lt;/div>&lt;div id="collapseFiveLeft-4" class="panel-collapse collapse" aria-expanded="false" role="tablist" style="height: 0px;">&lt;div class="panel-body">&lt;div class="text-accordion">&lt;p>無法確定。文中只提到全院共用服務中有圖書資訊，但沒有具體說明是提供員工借閱圖書的服務或其他相關的圖書資訊服務。需要進一步查閱該網頁或進行其他查詢才能確定。&lt;/p>&lt;/div>&lt;/div>&lt;/div>&lt;/div>&lt;/div>&lt;/div>&lt;/div>&lt;/div>&lt;div class="card">&lt;div class="card-header" id="heading-5">&lt;h5 class="mb-0">&lt;button class="btn btn-link collapsed" data-toggle="collapse" data-target="#collapse-5" aria-expanded="false" aria-controls="co ...
#
# 1. 獲得的免費額度較低。
# 2. 無法使用某些特定AWS服務。
# 3. 只能使用中研院信箱註冊，當身份離職或畢業於註銷信箱後，將無法收到相關通知信件。建議以AWS Account方式註冊。&lt;/p>&lt;/div>&lt;/div>&lt;/div>&lt;/div>&lt;div class="panel panel-default">&lt;div class="panel-heading">&lt;h4 class="panel-title">&lt;a data-toggle="collapse" data-parent="#accordion_oneLeft" href="#collapseFiveLeft-50" aria-expanded="false" class="collapsed">[AWS雲端服務方案] 如何申請AWS Educate方案？ &lt;/a>&lt;/h4>&lt;/div>&lt;div id="collapseFiveLeft-50" class="panel-collapse collapse" aria-expanded="false" role="tablist" style="height: 0px;">&lt;div class="panel-body">&lt;div class="text-accordion">&lt;p>申請AWS Educate方案可以採兩種方式，一種是使用AWS帳號註冊AWS Educate方案（AWS Account），另一種是使用中研院信箱註冊AWS Starter Account。申請流程、細節及獲得的免費額度也會因方案不同而有所不同。詳細資訊請參考中研院的網頁說明。&lt;/p>&lt;/div>&lt;/div>&lt;/div>&lt;/div>&lt;div class="panel panel-default">&lt;div class="panel-heading">&lt;h4 class="panel-title">&lt;a data-toggle="collapse" data-parent="#accordion_oneLeft" href="#collapseFiveLeft-51" aria-expanded="false" class="collapsed">[AWS雲端服務方案] 中研院的諮詢專線是多少？&lt;/a>&lt;/h4>&lt;/div>&lt;div id="collapseFiveLeft-51" class="panel-collapse collapse" aria-expanded="false" role="tablist" style="height: 0px;">&lt;div class="panel-body">&lt;div class="text-accordion">&lt;p>需要參考網頁說明 https://its.sinica.edu.tw/pages/1680 才能回答此問題。&lt;/p>&lt;/div>&lt;/div>&lt;/div>&lt;/div>&lt;div class="panel panel-default">&lt;div class="panel-heading">&lt;h4 class="panel-title">&lt;a data-toggle="collapse" data-parent="#accordion_oneLeft" href="#collapseFiveLeft-52" aria-expanded="false" class="collapsed">[網頁空間服務] 中研院網頁空間服務的網址預設是什麼？&lt;/a>&lt;/h4>&lt;/div>&lt;div id="collapseFiveLeft-52" class="panel-collapse collapse" aria-expanded="false" role="tablist" style="height: 0px;">&lt;div class="panel-body">&lt;div class="text-accordion">&lt;p>中研院網頁空間服務的網址預設為*.project.sinica.edu.tw。&lt;/p>&lt;/div>&lt;/div>&lt;/div>&lt;/div>&lt;div class="panel panel-default">&lt;div class="panel-heading">&lt;h4 class="panel-title">&lt;a data-toggle="collapse" data-parent="#accordion_oneLeft" href="#collapseFiveLeft-53" aria-expanded="false" class="collapsed">[網頁空間服務] 如何申請網頁空間服務的帳號？&lt;/a>&lt;/h4>&lt;/div>&lt;div id="collapseFiveLeft-53" class="panel-collapse collapse" aria-expanded="false" role="tablist" style="height: 0px;">&lt;div class="panel-body">&lt;div class="text-accordion">&lt;p>可至中研院網頁空間服務的「下載專區」下載「網頁空間服務申請單」，填妥後提出網頁空間服務帳號申請，並自行進行網頁上傳。&lt;/p>&lt;/div>&lt;/div>&lt;/div>&lt;/div>&lt;div class="panel panel-default">&lt;div class="panel-heading">&lt;h4 class="panel-title">&lt;a data-toggle="collapse" data-parent="#accordion_oneLeft" href="#collapseFiveLeft-54" aria-expanded="false" class="collapsed">[網頁空間服務] 在哪裡可以下載「網頁空間服務申請單」？&lt;/a>&lt;/h4>&lt;/div>&lt;div id="collapseFiveLeft-54" class="panel-collapse collapse" aria-expanded="false" role="tablist" style="height: 0px;">&lt;div class="panel-body">&lt;div class="text-accordion">&lt;p>可以在中研院網頁的「下載專區」下載「網頁空間服務申請單」。&lt;/p>&lt;/div>&lt;/div>&lt;/div>&lt;/div>&lt;div class="panel panel-default">&lt;div class="panel-heading">&lt;h4 class="panel-title">&lt;a data-toggle="collapse" data-parent="#accordion_oneLeft" href="#collapseFiveLeft-55" aria-expanded="false" class="collapsed">[網頁空間服務] 是否能提供動態網站需求的相關資訊？&lt;/a>&lt;/h4>&lt;/div>&lt;div id="collapseFiveLeft-55" class="panel-collapse collapse" aria-expanded="false" role="tablist" style="height: 0px;">&lt;div class="panel-body">&lt;div class="text-accordion">&lt;p>中研院網頁空間服務只提供靜態網頁空間服務，建議有動態網站需求的使用者使用自有雲服務。該文字說明中未提供更多與動態網站相關的資訊。&lt;/p>&lt;/div>&lt;/div>&lt;/div>&lt;/div>&lt;div class="panel panel-default">&lt;div class="panel-heading">&lt;h4 class="panel-title">&lt;a data-toggle="collapse" data-parent="#accordion_oneLeft" href="#collapseFiveLeft-56" aria-expanded="false" class="collapsed">[圖示資料] 圖示資料中包含哪些內容？&lt;/a>&lt;/h4>&lt;/div>&lt;div id="collapseFiveLeft-56" class="panel-collapse collapse" aria-expanded="false" role="tablist" style="height: 0px;">&lt;div class="panel-body">&lt;div class="text-accordion">&lt;p>圖示資料中包含電子賀卡圖檔和各種院區照片。&lt;/p>&lt;/div>&l ...
# 1. 封鎖不明收件者
# 2. 封鎖黑名單表列者
# 3. 封鎖病毒信件
# 4. 隔離已確認的垃圾信
# 5. 放行被加標記的疑似垃圾信以及放行正常信件。&lt;/p>&lt;/div>&lt;/div>&lt;/div>&lt;/div>&lt;div class="panel panel-default">&lt;div class="panel-heading">&lt;h4 class="panel-title">&lt;a data-toggle="collapse" data-parent="#accordion_oneLeft" href="#collapseFiveLeft-150" aria-expanded="false" class="collapsed">[電子郵件服務] 如果郵件被判斷為垃圾信，會發生什麼事情？&lt;/a>&lt;/h4>&lt;/div>&lt;div id="collapseFiveLeft-150" class="panel-collapse collapse" aria-expanded="false" role="tablist" style="height: 0px;">&lt;div class="panel-body">&lt;div class="text-accordion">&lt;p>被判斷為垃圾信的郵件會被置放在阻絕設備的隔離區，並發送當日的隔離通知信給使用者，內容包括每封垃圾信的日期、來源地址和主旨。使用者可以透過連線至信件隔離區，使用寄送、白名單、刪除等三種處理方式處理隔離區的垃圾信件。若不刪除，系統會保留約30天，並自動刪除過多的垃圾信件。&lt;/p>&lt;/div>&lt;/div>&lt;/div>&lt;/div>&lt;div class="panel panel-default">&lt;div class="panel-heading">&lt;h4 class="panel-title">&lt;a data-toggle="collapse" data-parent="#accordion_oneLeft" href="#collapseFiveLeft-151" aria-expanded="false" class="collapsed">[電子郵件服務] 使用者可以如何檢視隔離通知信的內容？&lt;/a>&lt;/h4>&lt;/div>&lt;div id="collapseFiveLeft-151" class="panel-collapse collapse" aria-expanded="false" role="tablist" style="height: 0px;">&lt;div class="panel-body">&lt;div class="text-accordion">&lt;p>使用者可以打開垃圾隔離區摘要信件，點選「看您所有的隔離信件」或「管理您的參數設定」，或使用中研院院內網路IP連線至https://fmail0.its.sinica.edu.tw，其他網域使用者連線至https://fmail3.its.sinica.edu.tw/，即可直接連結至隔離區，檢視隔離通知信的內容。&lt;/p>&lt;/div>&lt;/div>&lt;/div>&lt;/div>&lt;div class="panel panel-default">&lt;div class="panel-heading">&lt;h4 class="panel-title">&lt;a data-toggle="collapse" data-parent="#accordion_oneLeft" href="#collapseFiveLeft-152" aria-expanded="false" class="collapsed">[電子郵件服務] 連線至隔離區的方法有哪些？&lt;/a>&lt;/h4>&lt;/div>&lt;div id="collapseFiveLeft-152" class="panel-collapse collapse" aria-expanded="false" role="tablist" style="height: 0px;">&lt;div class="panel-body">&lt;div class="text-accordion">&lt;p>有兩個方法可以連線至信件隔離區，方法一打開垃圾隔離區摘要信件，點選看您所有的隔離信件或管理您的參數設定，會直接連結至隔離區；方法二若已經刪除所有垃圾隔離區摘要信件，使用中研院院內網路IP請連線至https://fmail0.its.sinica.edu.tw，其他網域使用者請連線https://fmail3.its.sinica.edu.tw/。&lt;/p>&lt;/div>&lt;/div>&lt;/div>&lt;/div>&lt;div class="panel panel-default">&lt;div class="panel-heading">&lt;h4 class="panel-title">&lt;a data-toggle="collapse" data-parent="#accordion_oneLeft" href="#collapseFiveLeft-153" aria-expanded="false" class="collapsed">[電子郵件服務] 隔離區中有哪兩個項目？&lt;/a>&lt;/h4>&lt;/div>&lt;div id="collapseFiveLeft-153" class="panel-collapse collapse" aria-expanded="false" role="tablist" style="height: 0px;">&lt;div class="panel-body">&lt;div class="text-accordion">&lt;p>隔離區中有隔離區信件和參數選擇兩個項目。&lt;/p>&lt;/div>&lt;/div>&lt;/div>&lt;/div>&lt;div class="panel panel-default">&lt;div class="panel-heading">&lt;h4 class="panel-title">&lt;a data-toggle="collapse" data-parent="#accordion_oneLeft" href="#collapseFiveLeft-154" aria-expanded="false" class="collapsed">[電子郵件服務] 在隔離區信件中可以進行哪些處理方式？&lt;/a>&lt;/h4>&lt;/div>&lt;div id="collapseFiveLeft-154" class="panel-collapse collapse" aria-expanded="false" role="tablist" style="height: 0px;">&lt;div class="panel-body">&lt;div class="text-accordion">&lt;p>在隔離區信件中可以進行寄送、白名單、刪除三種處理方式。&lt;/p>&lt;/div>&lt;/div>&lt;/div>&lt;/div>&lt;div class="panel panel-default">&lt;div class="panel-heading">&lt;h4 class="panel-title">&lt;a data-toggle="collapse" data-parent="#accordion_oneLeft" href="#collapseFiveLeft-155" aria-expanded="false" class="collapsed">[電子郵件服務] 若不刪除隔離區信件，系統會保留多久？&lt;/a>&lt;/h4>&lt;/div>&lt;div id="collapseFiveLeft-155" class="panel-collapse collapse" aria-expanded="false" role="tablist" style="height: 0px;">&lt;div class="panel-body">&lt;div class="text-accordion">&lt;p>系統會保留約30天，並自動刪除過多的垃圾信件。&lt;/p>&lt;/div>&lt;/div>&lt;/div>&lt;/div>&lt;div class="panel panel-default">&lt;div class="panel-heading">&lt;h4 class="panel-title">&lt;a data-toggle="collapse" data-parent="#accordion_oneLeft" href="#collapseFiveLeft-156" aria-expanded="false" class="collapsed">[電子郵件服務] . 隔離區參數選擇中有哪些項目？&lt;/a>&lt;/h4>&lt;/div>&lt;div id="collapseFiveLeft-156" class="panel-collapse collapse" aria-expanded="false" role="tablis ...
# 1. 登入電子郵件服務的webmail。
# 2. 點選「個人設定」。
# 3. 選擇「信箱安全」。
# 4. 選擇「登入紀錄」，確認是否有意外的登入紀錄。&lt;/p>&lt;/div>&lt;/div>&lt;/div>&lt;/div>&lt;div class="panel panel-default">&lt;div class="panel-heading">&lt;h4 class="panel-title">&lt;a data-toggle="collapse" data-parent="#accordion_oneLeft" href="#collapseFiveLeft-165" aria-expanded="false" class="collapsed">[電子郵件服務] 在使用中研院的電子郵件服務時，如果我收到登入成功通知但我並未登入，該如何處理？&lt;/a>&lt;/h4>&lt;/div>&lt;div id="collapseFiveLeft-165" class="panel-collapse collapse" aria-expanded="false" role="tablist" style="height: 0px;">&lt;div class="panel-body">&lt;div class="text-accordion">&lt;p>如果在使用中研院的電子郵件服務時，收到登入成功通知但本人並未登入，應立即進行以下步驟：
# 1. 確認自己的帳號密碼是否已經揭露或遭到盜用。
# 2. 更改自己的帳號密碼，並確保密碼強度達到足夠的安全性。
# 3. 經常使用webmail > 個人設定 > 信箱安全 > 登入紀錄功能來確認是否有意異常登入狀況。
# 4. 若懷疑帳號已被非法使用，應盡速聯繫中研院資訊處進行確認及處理。&lt;/p>&lt;/div>&lt;/div>&lt;/div>&lt;/div>&lt;div class="panel panel-default">&lt;div class="panel-heading">&lt;h4 class="panel-title">&lt;a data-toggle="collapse" data-parent="#accordion_oneLeft" href="#collapseFiveLeft-166" aria-expanded="false" class="collapsed">[電子郵件服務] 使用中研院的電子郵件服務，如果我持續收到登入失敗通知，是否有其他的防護措施或建議？&lt;/a>&lt;/h4>&lt;/div>&lt;div id="collapseFiveLeft-166" class="panel-collapse collapse" aria-expanded="false" role="tablist" style="height: 0px;">&lt;div class="panel-body">&lt;div class="text-accordion">&lt;p>如果您持續收到登入失敗通知，建議您可以透過webmail > 個人設定 > 信箱安全 > 登入紀錄功能來確認是否有意異常登入狀況。此外，也建議您可以進行密碼更改，確保密碼強度夠強，並避免使用相同的密碼於其他網站或帳號上。資訊處所提供的電子郵件服務也具備自動防禦暴力破解法功能，如單一登入位址(IP)反覆嘗試登入並且登入失敗，系統會自動阻擋該登入位址一段時間，以阻止該嘗試登入行為。如您仍有其他疑慮，建議直接聯繫中研院資訊處相關人員以獲得更詳細的建議和協助。&lt;/p>&lt;/div>&lt;/div>&lt;/div>&lt;/div>&lt;/div>&lt;/div>&lt;/div>&lt;/div>&lt;div class="card">&lt;div class="card-header" id="heading-167">&lt;h5 class="mb-0">&lt;button class="btn btn-link collapsed" data-toggle="collapse" data-target="#collapse-167" aria-expanded="false" aria-controls="collapse-167">&lt;h2>全院共用服務-圖書資訊&lt;/h2>&lt;/button>&lt;/h5>&lt;/div>&lt;div id="collapse-167" class="collapse" aria-labelledby="heading-167" data-parent="#accordion">&lt;div class="card-body">&lt;div class="panel-group" id="accordionFourLeft">&lt;div class="panel panel-default">&lt;div class="panel-heading">&lt;h4 class="panel-title">&lt;a data-toggle="collapse" data-parent="#accordion_oneLeft" href="#collapseFiveLeft-167" aria-expanded="false" class="collapsed">[文獻傳遞服務] 文獻傳遞服務是否提供國内圖書館未收藏之館藏的複印服務？&lt;/a>&lt;/h4>&lt;/div>&lt;div id="collapseFiveLeft-167" class="panel-collapse collapse" aria-expanded="false" role="tablist" style="height: 0px;">&lt;div class="panel-body">&lt;div class="text-accordion">&lt;p>是的，文獻傳遞服務提供國内圖書館未收藏之館藏的複印服務。&lt;/p>&lt;/div>&lt;/div>&lt;/div>&lt;/div>&lt;div class="panel panel-default">&lt;div class="panel-heading">&lt;h4 class="panel-title">&lt;a data-toggle="collapse" data-parent="#accordion_oneLeft" href="#collapseFiveLeft-168" aria-expanded="false" class="collapsed">[文獻傳遞服務] 本服務是否需要付費使用？額度為多少？由誰支付？&lt;/a>&lt;/h4>&lt;/div>&lt;div id="collapseFiveLeft-168" class="panel-collapse collapse" aria-expanded="false" role="tablist" style="height: 0px;">&lt;div class="panel-body">&lt;div class="text-accordion">&lt;p>是，本服務需要付費使用；額度為25萬元；由資訊服務處支付。&lt;/p>&lt;/div>&lt;/div>&lt;/div>&lt;/div>&lt;div class="panel panel-default">&lt;div class="panel-heading">&lt;h4 class="panel-title">&lt;a data-toggle="collapse" data-parent="#accordion_oneLeft" href="#collapseFiveLeft-169" aria-expanded="false" class="collapsed">[文獻傳遞服務] 如果超出額度，相關費用由誰負擔？&lt;/a>&lt;/h4>&lt;/div>&lt;div id="collapseFiveLeft-169" class="panel-collapse collapse" aria-expanded="false" role="tablist" style="height: 0px;">&lt;div class="panel-body">&lt;div class="text-accordion">&lt;p>超出額度的費用由申請單位自行負擔。&lt;/p>&lt;/div>&lt;/div>&lt;/div>&lt;/div>&lt;div class="panel panel-default">&lt;div class="panel-heading">&lt;h4 class="panel-title">&lt;a data-toggle="collapse" data-parent="#accordion_oneLeft" href="#collapseFiveLeft-170" aria-expanded="false" class="collapsed">[文獻傳遞服務] 申請詳細說明與方式可在哪裡找到？&lt;/a>&lt;/h4>&lt;/div>&lt;div id="collapseFiveLeft-170" class="panel-collapse collapse" aria-expanded="false" role="tablist" style="height: 0px;">&lt;div class="panel-body">&lt;div class="text-accordion">&lt;p>申請詳細說明與方式可在https://its.sinica.edu.tw/pages/1694找到。&lt;/p>&lt;/div>&lt;/div>&lt;/div>&lt;/div>&lt;div class="panel panel-default">&lt;div class="panel-heading">&lt;h4 class="panel-title">&lt;a data-toggle="collapse" data-parent="#accordion_oneLeft" href="#collapseFiveLeft-171" aria-expanded="false" class="collapsed">[圖書館服務入口網站] 請問圖書館服務入口網站提供哪些服務項目？&lt;/a>&lt;/h4>&lt;/div>&lt;div id="collapseFiveLeft-171" class="panel-collapse collapse" aria-expanded="false" role="tablist" style="height: 0px;">&lt;div class="panel-body">&lt;div class="text-accordion">&lt;p>圖書館服務入口網站提供的服務項目包括最新消息、圖書館導覽、館藏查詢、其他圖書館查詢、線上 ...
#
# 1. 網路設備移動或更換：將現有網路設備進行移動或更換，以提高網路效能和穩定性。
#
# 2. 網路佈線調整：對現有網路佈線進行調整，以改進網路效能和穩定性。
#
# 3. 網路擴建：根據用戶需求擴建現有網路，以支持更多的用戶。
#
# 4. 異動通知與協調：提供異動通知和協調工作，確保異動過程中不會對用戶造成太大的影響。&lt;/p>&lt;/div>&lt;/div>&lt;/div>&lt;/div>&lt;div class="panel panel-default">&lt;div class="panel-heading">&lt;h4 class="panel-title">&lt;a data-toggle="collapse" data-parent="#accordion_oneLeft" href="#collapseFiveLeft-215" aria-expanded="false" class="collapsed">[區域網路規劃與建置] 網路佈線與維護服務是針對哪些地點進行的？&lt;/a>&lt;/h4>&lt;/div>&lt;div id="collapseFiveLeft-215" class="panel-collapse collapse" aria-expanded="false" role="tablist" style="height: 0px;">&lt;div class="panel-body">&lt;div class="text-accordion">&lt;p>網路佈線與維護服務是針對中研院院本部及院內宿舍進行的。另外還包括活動中心、行政大樓及院本部下院內各學人及職務宿舍與建物網路連線服務等。&lt;/p>&lt;/div>&lt;/div>&lt;/div>&lt;/div>&lt;div class="panel panel-default">&lt;div class="panel-heading">&lt;h4 class="panel-title">&lt;a data-toggle="collapse" data-parent="#accordion_oneLeft" href="#collapseFiveLeft-216" aria-expanded="false" class="collapsed">[區域網路規劃與建置] 活動中心、行政大樓及院本部下院內的網路連線是由誰提供服務？&lt;/a>&lt;/h4>&lt;/div>&lt;div id="collapseFiveLeft-216" class="panel-collapse collapse" aria-expanded="false" role="tablist" style="height: 0px;">&lt;div class="panel-body">&lt;div class="text-accordion">&lt;p>由中研院提供服務。&lt;/p>&lt;/div>&lt;/div>&lt;/div>&lt;/div>&lt;div class="panel panel-default">&lt;div class="panel-heading">&lt;h4 class="panel-title">&lt;a data-toggle="collapse" data-parent="#accordion_oneLeft" href="#collapseFiveLeft-217" aria-expanded="false" class="collapsed">[區域網路規劃與建置] 活動中心、行政大樓及院本部下院內各學人及職務宿舍與建物的網路連線服務的內容是什麼？&lt;/a>&lt;/h4>&lt;/div>&lt;div id="collapseFiveLeft-217" class="panel-collapse collapse" aria-expanded="false" role="tablist" style="height: 0px;">&lt;div class="panel-body">&lt;div class="text-accordion">&lt;p>活動中心、行政大樓及院本部下院內各學人及職務宿舍與建物的網路連線服務的內容沒有具體說明，建議詢問相關單位以了解詳情。&lt;/p>&lt;/div>&lt;/div>&lt;/div>&lt;/div>&lt;div class="panel panel-default">&lt;div class="panel-heading">&lt;h4 class="panel-title">&lt;a data-toggle="collapse" data-parent="#accordion_oneLeft" href="#collapseFiveLeft-218" aria-expanded="false" class="collapsed">[郵件伺服器集中過濾服務] 這項服務是否只提供給中研院各所(處)、中心使用，或是否開放給其他機構或個人使用？&lt;/a>&lt;/h4>&lt;/div>&lt;div id="collapseFiveLeft-218" class="panel-collapse collapse" aria-expanded="false" role="tablist" style="height: 0px;">&lt;div class="panel-body">&lt;div class="text-accordion">&lt;p>根據提供的文字說明，無法確定此服務是否開放給其他機構或個人使用。&lt;/p>&lt;/div>&lt;/div>&lt;/div>&lt;/div>&lt;div class="panel panel-default">&lt;div class="panel-heading">&lt;h4 class="panel-title">&lt;a data-toggle="collapse" data-parent="#accordion_oneLeft" href="#collapseFiveLeft-219" aria-expanded="false" class="collapsed">[郵件伺服器集中過濾服務] 這項服務如何過濾病毒和垃圾郵件？使用了哪些技術或方法？&lt;/a>&lt;/h4>&lt;/div>&lt;div id="collapseFiveLeft-219" class="panel-collapse collapse" aria-expanded="false" role="tablist" style="height: 0px;">&lt;div class="panel-body">&lt;div class="text-accordion">&lt;p>這項服務使用了Email server集中的過濾技術，可能採用如防火牆、SPF、DKIM、DMARC、黑名單、白名單、異常行為偵測等多種技術或方法來過濾病毒和垃圾郵件。具體使用哪些技術或方法，則需要進一步詳細了解中研院所使用的郵件系統和相關配套措施。&lt;/p>&lt;/div>&lt;/div>&lt;/div>&lt;/div>&lt;div class="panel panel-default">&lt;div class="panel-heading">&lt;h4 class="panel-title">&lt;a data-toggle="collapse" data-parent="#accordion_oneLeft" href="#collapseFiveLeft-220" aria-expanded="false" class="collapsed">[郵件伺服器集中過濾服務] 過濾是否只限於中研院各所(處)、中心的電子郵件服務，或是否可適用於其他電子郵件提供商或自建伺服器？&lt;/a>&lt;/h4>&lt;/div>&lt;div id="collapseFiveLeft-220" class="panel-collapse collapse" aria-expanded="false" role="tablist" style="height: 0px;">&lt;div class="panel-body">&lt;div class="text-accordion">&lt;p>根據文字說明，該服務僅針對中研院各所(處)、中心的Email server集中過濾病毒與垃圾郵件，因此不適用於其他電子郵件提供商或自建伺服器。&lt;/p>&lt;/div>&lt;/div>&lt;/div>&lt;/div>&lt;div class="panel panel-default">&lt;div class="panel-heading">&lt;h4 class="panel-title">&lt;a data-toggle="collapse" data-parent="#accordion_oneLeft" href="#collapseFiveLeft-221" aria-expanded="false" class="collapsed">[郵件伺服器集中過濾服務] 這項服務提供哪些額外的功能或設定，例如白名單、黑名單、自訂過濾規則等？&lt;/a>&lt;/h4>&lt;/div>&lt;div id="collapseFiveLeft-221" class="panel-collapse collapse" aria-expanded="false" role="tab ...
# 1. 登入 Tenable Security Center 平台。
# 2. 設定掃描範圍和時間。
# 3. 運行弱點掃描。
# 4. 分析掃描結果，評估風險和分類弱點。
# 5. 根據風險等級和可行性制定計劃，進行修補或漏洞管理。
# 6. 在進行修補或漏洞管理後，再次運行弱點掃描，確保修復了所有弱點。&lt;/p>&lt;/div>&lt;/div>&lt;/div>&lt;/div>&lt;div class="panel panel-default">&lt;div class="panel-heading">&lt;h4 class="panel-title">&lt;a data-toggle="collapse" data-parent="#accordion_oneLeft" href="#collapseFiveLeft-250" aria-expanded="false" class="collapsed">[全院型主機弱點掃描服務平台] 這個平台是否可以協助中心評估和管理主機弱點和威脅？&lt;/a>&lt;/h4>&lt;/div>&lt;div id="collapseFiveLeft-250" class="panel-collapse collapse" aria-expanded="false" role="tablist" style="height: 0px;">&lt;div class="panel-body">&lt;div class="text-accordion">&lt;p>是的，該平台能以系統化方式檢測及管理主機弱點，有效協助各所中心評估與管理各項主機弱點及威脅。&lt;/p>&lt;/div>&lt;/div>&lt;/div>&lt;/div>&lt;div class="panel panel-default">&lt;div class="panel-heading">&lt;h4 class="panel-title">&lt;a data-toggle="collapse" data-parent="#accordion_oneLeft" href="#collapseFiveLeft-251" aria-expanded="false" class="collapsed">[全院型主機弱點掃描服務平台] 是否有其他詳細的服務說明可以參考？&lt;/a>&lt;/h4>&lt;/div>&lt;div id="collapseFiveLeft-251" class="panel-collapse collapse" aria-expanded="false" role="tablist" style="height: 0px;">&lt;div class="panel-body">&lt;div class="text-accordion">&lt;p>是的，詳細的服務說明可以參考 https://its.sinica.edu.tw/pages/3608。&lt;/p>&lt;/div>&lt;/div>&lt;/div>&lt;/div>&lt;div class="panel panel-default">&lt;div class="panel-heading">&lt;h4 class="panel-title">&lt;a data-toggle="collapse" data-parent="#accordion_oneLeft" href="#collapseFiveLeft-252" aria-expanded="false" class="collapsed">[網頁弱點掃描] 這個網頁弱點掃描服務是由哪一個單位提供的？&lt;/a>&lt;/h4>&lt;/div>&lt;div id="collapseFiveLeft-252" class="panel-collapse collapse" aria-expanded="false" role="tablist" style="height: 0px;">&lt;div class="panel-body">&lt;div class="text-accordion">&lt;p>這個網頁弱點掃描服務是由中研院資訊服務處提供的。&lt;/p>&lt;/div>&lt;/div>&lt;/div>&lt;/div>&lt;div class="panel panel-default">&lt;div class="panel-heading">&lt;h4 class="panel-title">&lt;a data-toggle="collapse" data-parent="#accordion_oneLeft" href="#collapseFiveLeft-253" aria-expanded="false" class="collapsed">[網頁弱點掃描] 他們使用哪一個工具來進行網頁弱點掃描？&lt;/a>&lt;/h4>&lt;/div>&lt;div id="collapseFiveLeft-253" class="panel-collapse collapse" aria-expanded="false" role="tablist" style="height: 0px;">&lt;div class="panel-body">&lt;div class="text-accordion">&lt;p>他們使用自動化弱點掃描工具WebInspect來掃描網頁資安相關漏洞。&lt;/p>&lt;/div>&lt;/div>&lt;/div>&lt;/div>&lt;div class="panel panel-default">&lt;div class="panel-heading">&lt;h4 class="panel-title">&lt;a data-toggle="collapse" data-parent="#accordion_oneLeft" href="#collapseFiveLeft-254" aria-expanded="false" class="collapsed">[網頁弱點掃描] 這個服務的目的是什麼？&lt;/a>&lt;/h4>&lt;/div>&lt;div id="collapseFiveLeft-254" class="panel-collapse collapse" aria-expanded="false" role="tablist" style="height: 0px;">&lt;div class="panel-body">&lt;div class="text-accordion">&lt;p>這個服務的目的是為了檢測網頁應用程式和動態程式碼的安全性，提供快速和精確的解決方案和報表檢閱，以簡化發現和修復網頁應用程式安全性問題的工作，降低維護資訊安全的成本。&lt;/p>&lt;/div>&lt;/div>&lt;/div>&lt;/div>&lt;div class="panel panel-default">&lt;div class="panel-heading">&lt;h4 class="panel-title">&lt;a data-toggle="collapse" data-parent="#accordion_oneLeft" href="#collapseFiveLeft-255" aria-expanded="false" class="collapsed">[網頁弱點掃描] 如果我想要申請這個服務，我應該如何填寫申請表格？&lt;/a>&lt;/h4>&lt;/div>&lt;div id="collapseFiveLeft-255" class="panel-collapse collapse" aria-expanded="false" role="tablist" style="height: 0px;">&lt;div class="panel-body">&lt;div class="text-accordion">&lt;p>如果想要申請網頁檢測服務，可以填寫資訊服務處的電子服務台之服務洽詢單(https://8855.sinica.edu.tw)，並提供掃描標的名稱、IP和網址。&lt;/p>&lt;/div>&lt;/div>&lt;/div>&lt;/div>&lt;div class="panel panel-default">&lt;div class="panel-heading">&lt;h4 class="panel-title">&lt;a data-toggle="collapse" data-parent="#accordion_oneLeft" href="#collapseFiveLeft-256" aria-expanded="false" class="collapsed">[網頁弱點掃描] 掃描完成後，他們會提供哪些資訊給客戶？&lt;/a>&lt;/h4>&lt;/div>&lt;div id="collapseFiveLeft-256" class="panel-collapse collapse" aria-expanded="false" role="tablist" style="height: 0px;">&lt;div class="panel-body">&lt;div class="text-accordion">&lt;p>掃瞄完成後，資訊服務處會提供漏洞資訊、修改建議和諮詢服務。&lt;/p>&lt;/div>&lt;/div>&lt;/div>&lt;/div>&lt;div cl ...
# 1. 人员管理暨资通安全训练。
# 2. 电脑机房安全管理。
# 3. 网络安全管理。
# 4. 电脑系统安全管理。
# 5. 应用系统存取控制管理。
# 6. 应用系统开发及维护安全管理。
# 7. 电子资料安全管理。
# 8. 个人资料保护暨安全维护。
# 9. 其他有关资通安全、个人资料保护等事项。&lt;/p>&lt;/div>&lt;/div>&lt;/div>&lt;/div>&lt;div class="panel panel-default">&lt;div class="panel-heading">&lt;h4 class="panel-title">&lt;a data-toggle="collapse" data-parent="#accordion_oneLeft" href="#collapseFiveLeft-277" aria-expanded="false" class="collapsed">[資安政策介紹] 資通安全長的職責是什麼？&lt;/a>&lt;/h4>&lt;/div>&lt;div id="collapseFiveLeft-277" class="panel-collapse collapse" aria-expanded="false" role="tablist" style="height: 0px;">&lt;div class="panel-body">&lt;div class="text-accordion">&lt;p>資通安全長由副院長或秘書長擔任，主管全院資通安全事務。&lt;/p>&lt;/div>&lt;/div>&lt;/div>&lt;/div>&lt;div class="panel panel-default">&lt;div class="panel-heading">&lt;h4 class="panel-title">&lt;a data-toggle="collapse" data-parent="#accordion_oneLeft" href="#collapseFiveLeft-278" aria-expanded="false" class="collapsed">[資安政策介紹] 中研院應設哪些組織或單位負責資通安全相關事項？&lt;/a>&lt;/h4>&lt;/div>&lt;div id="collapseFiveLeft-278" class="panel-collapse collapse" aria-expanded="false" role="tablist" style="height: 0px;">&lt;div class="panel-body">&lt;div class="text-accordion">&lt;p>中研院應設資通安全長、資通安全暨個人資料保護委員會、資通安全主管與資通安全聯絡人、資通安全稽核小組、資通安全事件處理小組、業務承辦單位或使用單位，以及政風室等組織或單位負責資通安全相關事項。&lt;/p>&lt;/div>&lt;/div>&lt;/div>&lt;/div>&lt;div class="panel panel-default">&lt;div class="panel-heading">&lt;h4 class="panel-title">&lt;a data-toggle="collapse" data-parent="#accordion_oneLeft" href="#collapseFiveLeft-279" aria-expanded="false" class="collapsed">[資安政策介紹] 為降低資通安全事件造成的損害，應建立哪些通報與處理程序？&lt;/a>&lt;/h4>&lt;/div>&lt;div id="collapseFiveLeft-279" class="panel-collapse collapse" aria-expanded="false" role="tablist" style="height: 0px;">&lt;div class="panel-body">&lt;div class="text-accordion">&lt;p>為降低資通安全事件造成的損害，應建立相關通報與處理程序，並詳加記錄。具體的通報與處理程序則沒有在此文字說明中詳細說明。&lt;/p>&lt;/div>&lt;/div>&lt;/div>&lt;/div>&lt;div class="panel panel-default">&lt;div class="panel-heading">&lt;h4 class="panel-title">&lt;a data-toggle="collapse" data-parent="#accordion_oneLeft" href="#collapseFiveLeft-280" aria-expanded="false" class="collapsed">[資安規章] 中央研究院為什麼會訂定這份資安規章？&lt;/a>&lt;/h4>&lt;/div>&lt;div id="collapseFiveLeft-280" class="panel-collapse collapse" aria-expanded="false" role="tablist" style="height: 0px;">&lt;div class="panel-body">&lt;div class="text-accordion">&lt;p>中央研究院訂定這份資安規章是為了落實個人資料保護法之依法管理及安全維護。&lt;/p>&lt;/div>&lt;/div>&lt;/div>&lt;/div>&lt;div class="panel panel-default">&lt;div class="panel-heading">&lt;h4 class="panel-title">&lt;a data-toggle="collapse" data-parent="#accordion_oneLeft" href="#collapseFiveLeft-281" aria-expanded="false" class="collapsed">[資安規章] 這份規範的用詞定義有哪些？可以舉例說明嗎？&lt;/a>&lt;/h4>&lt;/div>&lt;div id="collapseFiveLeft-281" class="panel-collapse collapse" aria-expanded="false" role="tablist" style="height: 0px;">&lt;div class="panel-body">&lt;div class="text-accordion">&lt;p>這份規範的用詞定義有四個，分別是個資欄位、個資紀錄、個資去識別化、本院法定職務。舉例來說，個資去識別化指的是藉由代碼替換、刪除或隱藏部分個資欄位，使該個資紀錄無法直接識別當事人。&lt;/p>&lt;/div>&lt;/div>&lt;/div>&lt;/div>&lt;div class="panel panel-default">&lt;div class="panel-heading">&lt;h4 class="panel-title">&lt;a data-toggle="collapse" data-parent="#accordion_oneLeft" href="#collapseFiveLeft-282" aria-expanded="false" class="collapsed">[資安規章] 蒐集、處理或利用個資的目的應該與什麼相符？有哪些合法依據可以利用個資？&lt;/a>&lt;/h4>&lt;/div>&lt;div id="collapseFiveLeft-282" class="panel-collapse collapse" aria-expanded="false" role="tablist" style="height: 0px;">&lt;div class="panel-body">&lt;div class="text-accordion">&lt;p>蒐集、處理或利用個資的目的應該與執行本院法定職務相符，且利用個資應與蒐集之特定目的相符，或具備個資法第十六條但書之合法依據。合法依據可以是個資法第十六條規定的例外事項，如但書所列舉的等同目的、公共利益、法律義務履行、當事人明示同意等情況。&lt;/p>&lt;/div>&lt;/div>&lt;/div>&lt;/div>&lt;div class="panel panel-default">&lt;div class="panel-heading">&lt;h4 class="panel-title">&lt;a data-toggle="collapse" data-parent="#accordion_oneLeft" href="#collapseFiveLeft-283" aria-expanded="false" class="collapsed">[資安規章] 個人填寫的個資內容是否需要經過本院相關法定職務執行人員查證？&lt;/a>&lt;/h4>&lt;/div>&lt;div id="collapseFiveLeft-283" class="panel-collapse collapse" aria-expanded="false" role="tablist" style="height: 0px;">&lt;div class="panel-body">&lt;div class=" ...
# 1. 辦理當事人依個資法第十條及第十一條第一項至第四項所定請求事項之考核。
# 2. 辦理個資法第十一條第五項及第十二條所定通知事項之考核。
# 3. 個資法第十七條所定公開或供公眾查閱。
# 4. 個資法第十八條所定個人資料檔案安全維護。
# 5. 個資保護事項之協調聯繫。
# 6. 單位內個資損害預防及危機處理應變之通報。
# 7. 個資保護之自行查核及本院個資保護規章之執行。&lt;/p>&lt;/div>&lt;/div>&lt;/div>&lt;/div>&lt;div class="panel panel-default">&lt;div class="panel-heading">&lt;h4 class="panel-title">&lt;a data-toggle="collapse" data-parent="#accordion_oneLeft" href="#collapseFiveLeft-290" aria-expanded="false" class="collapsed">[資安規章] . 本院院本部的個資保護聯絡窗口負責處理哪些事項？&lt;/a>&lt;/h4>&lt;/div>&lt;div id="collapseFiveLeft-290" class="panel-collapse collapse" aria-expanded="false" role="tablist" style="height: 0px;">&lt;div class="panel-body">&lt;div class="text-accordion">&lt;p>本院院本部的個資保護聯絡窗口負責處理以下事項：
# 1.公務機關間個人資料保護業務之協調聯繫及緊急應變通報。
# 2.以非自動化方式檢索、整理之個人資料安全事件之通報。
# 3.重大個人資料外洩事件之民眾聯繫單一窗口。
# 4.本院及所屬單位個資專人名冊之製作及更新。
# 5.本院及所屬單位個資專人與職員工教育訓練名單及紀錄之彙整。&lt;/p>&lt;/div>&lt;/div>&lt;/div>&lt;/div>&lt;div class="panel panel-default">&lt;div class="panel-heading">&lt;h4 class="panel-title">&lt;a data-toggle="collapse" data-parent="#accordion_oneLeft" href="#collapseFiveLeft-291" aria-expanded="false" class="collapsed">[資安規章] 資通安全暨個人資料保護委員會的職責是什麼？&lt;/a>&lt;/h4>&lt;/div>&lt;div id="collapseFiveLeft-291" class="panel-collapse collapse" aria-expanded="false" role="tablist" style="height: 0px;">&lt;div class="panel-body">&lt;div class="text-accordion">&lt;p>資通安全暨個人資料保護委員會的職責包括：人員管理暨資通安全訓練、電腦機房安全管理、網路安全管理、電腦系統安全管理、應用系統存取控制管理、應用系統發展及維護安全管理、電子資料安全管理、個人資料安全維護規定、資通安全管理制度推動，以及其他有關資通安全及個人資料保護事項。&lt;/p>&lt;/div>&lt;/div>&lt;/div>&lt;/div>&lt;div class="panel panel-default">&lt;div class="panel-heading">&lt;h4 class="panel-title">&lt;a data-toggle="collapse" data-parent="#accordion_oneLeft" href="#collapseFiveLeft-292" aria-expanded="false" class="collapsed">[資安規章] 委員會成員是由誰擔任的？&lt;/a>&lt;/h4>&lt;/div>&lt;div id="collapseFiveLeft-292" class="panel-collapse collapse" aria-expanded="false" role="tablist" style="height: 0px;">&lt;div class="panel-body">&lt;div class="text-accordion">&lt;p>中研院資通安全暨個人資料保護委員會置委員十九至二十三人，其中當然委員，由本院資通安全長、資訊業務諮議委員會召集人、資訊科學研究所所長、資訊科技創新研究中心主任及院本部各處室主管擔任；聘任委員六至八人。其中三人由資訊業務諮議委員會推薦。召集人為會議主席，召集人未能出席時，指定委員一名代理之。&lt;/p>&lt;/div>&lt;/div>&lt;/div>&lt;/div>&lt;div class="panel panel-default">&lt;div class="panel-heading">&lt;h4 class="panel-title">&lt;a data-toggle="collapse" data-parent="#accordion_oneLeft" href="#collapseFiveLeft-293" aria-expanded="false" class="collapsed">[資安規章] 委員會秘書由誰負責辦理？&lt;/a>&lt;/h4>&lt;/div>&lt;div id="collapseFiveLeft-293" class="panel-collapse collapse" aria-expanded="false" role="tablist" style="height: 0px;">&lt;div class="panel-body">&lt;div class="text-accordion">&lt;p>委員會秘書作業由資訊服務處負責辦理。&lt;/p>&lt;/div>&lt;/div>&lt;/div>&lt;/div>&lt;div class="panel panel-default">&lt;div class="panel-heading">&lt;h4 class="panel-title">&lt;a data-toggle="collapse" data-parent="#accordion_oneLeft" href="#collapseFiveLeft-294" aria-expanded="false" class="collapsed">[資安規章] 委員會每六個月召開一次會議嗎？另外還會召開其他類型的會議嗎？&lt;/a>&lt;/h4>&lt;/div>&lt;div id="collapseFiveLeft-294" class="panel-collapse collapse" aria-expanded="false" role="tablist" style="height: 0px;">&lt;div class="panel-body">&lt;div class="text-accordion">&lt;p>是的，中研院资通安全暨个人资料保护委员会每六个月召开一次会议。如果有必要，还可以召开临时会议。&lt;/p>&lt;/div>&lt;/div>&lt;/div>&lt;/div>&lt;div class="panel panel-default">&lt;div class="panel-heading">&lt;h4 class="panel-title">&lt;a data-toggle="collapse" data-parent="#accordion_oneLeft" href="#collapseFiveLeft-295" aria-expanded="false" class="collapsed">[資安規章] 資安規章的主要目的是什麼？ &lt;/a>&lt;/h4>&lt;/div>&lt;div id="collapseFiveLeft-295" class="panel-collapse collapse" aria-expanded="false" role="tablist" style="height: 0px;">&lt;div class="panel-body">&lt;div class="text-accordion">&lt;p>資安規章的主要目的是確保電子形式軌跡資料的蒐集、處理及利用符合資通安全及資訊隱私之維護。&lt;/p>&lt;/div>&lt;/div>&lt;/div>&lt;/div>&lt;div class="panel panel-default">&lt;div class="panel-heading">&lt;h4 class="panel-title">&lt;a data-toggle="collapse" data-parent="#accordion_oneLeft" href="#collapseFiveLeft-296" aria-expanded="false" class="collapsed">[資安規章] 何謂Log? &lt;/a>&lt;/h4>&lt;/div>&lt;div id="collapseFiveLeft-296" class="panel-collapse collapse" aria-expanded="false" role="tablist" style="height: 0px;">&lt;div class="panel-body">&lt;div class="text-accordion">&lt;p>Log是指在使用資通系統服務過程中，由作業系統、應用系統、資安設備、網路設備等軟硬體自動產生使用狀態之紀錄，包括但不限於使用者之存取帳號、存取時間、網路 IP 位址、使用設備代號、網路路徑等使用資通系統之紀錄。&lt;/p>&lt;/div>&lt;/div>&lt;/div>&lt;/div>&lt;div class="panel panel-default">&lt;div class="panel-heading">&lt;h4 class="panel-title">&lt;a data-toggle="collapse" data-parent="#accordion_oneLeft" href="#collapseFiveLeft-297" aria-expanded="false" class="collapsed">[資安規章] 本要點適用範圍是什麼？ &lt;/a>&lt;/h4>&lt;/div>&lt;div id="collapseFiveLeft-297" class="panel-collapse collapse" aria-expanded="false" role="tablist" style="height: 0px;">&lt;div class="panel-body">&lt;d ...
# (一) 申請閱覽或提供複製本。
# (二) 不宜以口頭答覆者。&lt;/p>&lt;/div>&lt;/div>&lt;/div>&lt;/div>&lt;div class="panel panel-default">&lt;div class="panel-heading">&lt;h4 class="panel-title">&lt;a data-toggle="collapse" data-parent="#accordion_oneLeft" href="#collapseFiveLeft-301" aria-expanded="false" class="collapsed">[資安規章] 調閱Log的審核程序是怎樣的？ &lt;/a>&lt;/h4>&lt;/div>&lt;div id="collapseFiveLeft-301" class="panel-collapse collapse" aria-expanded="false" role="tablist" style="height: 0px;">&lt;div class="panel-body">&lt;div class="text-accordion">&lt;p>調閱Log的審核程序包括以下步驟：
# 1. Log管理者接受口頭申請並口頭答覆，若需要閱覽、提供複製本，或不宜以口頭答覆者，則需以書面申請。
# 2. 若以書面申請，Log主管需報請單位主管核准得調閱之Log項目及內容；申請人為單位主管者，由單位副主管或最資深研究人員核准之。
# 3. Log主管及管理者需保護調閱申請之紀錄及資訊機密性。
# 4. 調閱的範圍及內容以解決資通安全威脅所必要之最少資料為限。調閱涉及第三人之使用紀錄時，須通知該第三人。&lt;/p>&lt;/div>&lt;/div>&lt;/div>&lt;/div>&lt;div class="panel panel-default">&lt;div class="panel-heading">&lt;h4 class="panel-title">&lt;a data-toggle="collapse" data-parent="#accordion_oneLeft" href="#collapseFiveLeft-302" aria-expanded="false" class="collapsed">[資安規章] Log管理者有哪些責任？ &lt;/a>&lt;/h4>&lt;/div>&lt;div id="collapseFiveLeft-302" class="panel-collapse collapse" aria-expanded="false" role="tablist" style="height: 0px;">&lt;div class="panel-body">&lt;div class="text-accordion">&lt;p>Log管理者有以下責任：
# 1. Log之保存與稽核。
# 2. 為維護資通系統安全所為之威脅分析與因應。
# 3. 資安事件之調查處理。&lt;/p>&lt;/div>&lt;/div>&lt;/div>&lt;/div>&lt;div class="panel panel-default">&lt;div class="panel-heading">&lt;h4 class="panel-title">&lt;a data-toggle="collapse" data-parent="#accordion_oneLeft" href="#collapseFiveLeft-303" aria-expanded="false" class="collapsed">[資安規章] 各單位應該公告什麼政策？&lt;/a>&lt;/h4>&lt;/div>&lt;div id="collapseFiveLeft-303" class="panel-collapse collapse" aria-expanded="false" role="tablist" style="height: 0px;">&lt;div class="panel-body">&lt;div class="text-accordion">&lt;p>各單位應公告隱私權政策，聲明該管資通系統為維護系統安全將自動記錄整體或個別使用者Log之類別及其利用方式。&lt;/p>&lt;/div>&lt;/div>&lt;/div>&lt;/div>&lt;div class="panel panel-default">&lt;div class="panel-heading">&lt;h4 class="panel-title">&lt;a data-toggle="collapse" data-parent="#accordion_oneLeft" href="#collapseFiveLeft-304" aria-expanded="false" class="collapsed">[資安規章] 什麼是中央研究院公務用途使用即時通訊軟體指引？&lt;/a>&lt;/h4>&lt;/div>&lt;div id="collapseFiveLeft-304" class="panel-collapse collapse" aria-expanded="false" role="tablist" style="height: 0px;">&lt;div class="panel-body">&lt;div class="text-accordion">&lt;p>中央研究院公務用途使用即時通訊軟體指引是一份文件，旨在提高中央研究院同仁使用即時通訊軟體處理公務時的安全性，防範資訊安全風險，並提供使用建議予各單位參考。&lt;/p>&lt;/div>&lt;/div>&lt;/div>&lt;/div>&lt;div class="panel panel-default">&lt;div class="panel-heading">&lt;h4 class="panel-title">&lt;a data-toggle="collapse" data-parent="#accordion_oneLeft" href="#collapseFiveLeft-305" aria-expanded="false" class="collapsed">[資安規章] 中央研究院有推薦的即時通訊軟體嗎？為什麼推薦這些軟體？&lt;/a>&lt;/h4>&lt;/div>&lt;div id="collapseFiveLeft-305" class="panel-collapse collapse" aria-expanded="false" role="tablist" style="height: 0px;">&lt;div class="panel-body">&lt;div class="text-accordion">&lt;p>中央研究院有推薦使用SKI+即時通訊軟體，原因是該軟體具備點對點加密功能，且由中研院專業團隊建置，伺服器由可靠機構維運，因此具有較高的安全性。此外，如果需要使用其他通訊軟體，也建議選擇具備點對點加密功能且伺服器建置於台灣境內的軟體。&lt;/p>&lt;/div>&lt;/div>&lt;/div>&lt;/div>&lt;div class="panel panel-default">&lt;div class="panel-heading">&lt;h4 class="panel-title">&lt;a data-toggle="collapse" data-parent="#accordion_oneLeft" href="#collapseFiveLeft-306" aria-expanded="false" class="collapsed">[資安規章] 如果需要使用其他通訊軟體，有什麼考慮事項？&lt;/a>&lt;/h4>&lt;/div>&lt;div id="collapseFiveLeft-306" class="panel-collapse collapse" aria-expanded="false" role="tablist" style="height: 0px;">&lt;div class="panel-body">&lt;div class="text-accordion">&lt;p>如果需要使用其他通訊軟體，建議考慮以下事項：
# 1. 該通訊軟體是否具備點對點加密功能。
# 2. 該通訊軟體伺服器宜建置於台灣境內。&lt;/p>&lt;/div>&lt;/div>&lt;/div>&lt;/div>&lt;div class="panel panel-default">&lt;div class="panel-heading">&lt;h4 class="panel-title">&lt;a data-toggle="collapse" data-parent="#accordion_oneLeft" href="#collapseFiveLeft-307" aria-expanded="false" class="collapsed">[資安規章] 安裝即時通訊軟體時需要注意什麼？&lt;/a>&lt;/h4>&lt;/div>&lt;div id="collapseFiveLeft-307" class="panel-collapse collapse" aria-expanded="false" role="tablist" style="height: 0px;">&lt;div class="panel-body">&lt;div class="text-accordion">&lt;p>安裝即時通訊軟體時需要注意以下幾點：
# 1. 軟體的安裝要透過官方網站下載，避免透過未知來源下載使用。
# 2. 安裝時要授權軟體必要使用權限，避免洩露過多個人資訊。
# 3. 要依各廠牌即時通訊軟體原廠建議進行安全設定。
# 4. 安裝電腦、筆電上要安裝防毒與端點防護軟體且保持正常運作。
# 5. 使用動裝置要有取得超級使用者權限等破壞原廠安全機制之行為。
# 6. 裝置之系統及通訊軟體版本必須保持最新版本，確保使用安全。&lt;/p>&lt;/div>&lt;/div>&lt;/div>&lt;/div>&lt;div class="panel panel-default">&lt;div class="panel-heading">&lt;h4 class="panel-title">&lt;a data-toggle="collapse" data-parent="#accordion_oneLeft" href="#collapseFiveLeft-308" aria-expanded="false" class="collapsed">[資安規章] 使用即時通訊軟體時需要注意哪些事項？&lt;/a>&lt;/h4>&lt;/div>&lt;div id="collapseFiveLeft-308" class="panel-collapse collapse" aria-expanded="false" role="tablist" style="height: 0px;">&lt;div class="panel-body">&lt;div class="text-accordion">&lt;p>使用即時通訊軟體時需要注意以下事項：
# 1. 建議使用本院提供的 SKI+ 軟體，具備點對點加密功能，伺服器由可靠機構維運。
# 2. 若使用其他通訊軟體，須選擇具備點對點加密功能且伺服器建置於台灣境內的軟體。
# 3. 安裝軟體時要從官方網站下載，勿隨意透過未知來源下載使用。
# 4. 安裝時需授權必要使用權限，並按照原廠建議進行安全設定。
# 5. 使用電腦、筆電安裝防毒與端點防護軟體，且系統及軟體版本須保持最新。
# 6. 傳送溝通訊息時要避免涉及機密性、安全性、隱私性、敏感性或個人資訊。
# 7. 不要隨意散佈通訊內容至任何公開或特定公開的網站。
# 8. 不要隨意點選訊息內超連結，以免進入釣魚、惡意或高風險網站陷阱。
# 9. 注意工作群組是否有陌生人士潛入，避免資訊外洩。&lt;/p>&lt;/div>&lt;/div>&lt;/div>&lt;/div>&lt;div class="panel panel-default">&lt;div class="panel-heading">&lt;h4 class="panel-title">&lt;a data-toggle="collapse" data-parent="#accordion_oneLeft" href="#collapseFiveLeft-309" aria-expanded="false" class="collapsed">[資安規章] 如何避免資訊外洩？&lt;/a>&lt;/h4>&lt;/div>&lt;div id="collapseFiveLeft-309" class="panel-collapse collapse" aria-expanded="false" role="tablist" style="height: 0px;">&lt;div class="panel-body">&lt;div class="text-accordion">&lt;p>隨時注意工作群組是否有陌生人士潛入，避免資訊外洩。使用即時通訊軟體以傳送溝通訊息為主，內容避免涉及機密性、安全性、隱私性、敏感性或洩漏個人資料。不要隨意以任何形式散佈通訊內容至任何公開或特定公開之網站。&lt;/p>&lt;/div>&lt;/div>&lt;/div>&lt;/div>&lt;div class="panel panel-default">&lt;div class="panel-heading">&lt;h4 class="panel-title">&lt;a data-toggle="collapse" data-parent="#accordion_oneLeft" href="#collapseFiveLeft-310" aria-expanded="false" class="collapsed">[資安規章] 這項服務的目的是什麼？&lt;/a>&lt;/h4>&lt;/div>&lt;div id="collapseFiveLeft-310" class="panel-collapse collapse" aria-expanded="false" role="tablist" style="height: 0px;">&lt;div class="panel-body">&lt;div class="text-accordion">&lt;p>這項服務的目的是提供中研院同仁使用自攜電子設備的使用建議，以防止因資安防護或管控不足，導致公務資訊系統遭駭、資料外洩等風險。&lt;/p>&lt;/div>&lt;/div>&lt;/div>&lt;/div>&lt;div class="panel panel-default">&lt;div class="panel-heading">&lt;h4 class="panel-title">&lt;a data-toggle="collapse" data-parent="#accordion_oneLeft" href="#collapseFiveLeft-311" aria-expanded="false" class="collapsed">[資安規章] 這項服務適用於哪些區域？&lt;/a>&lt;/h4>&lt;/div>&lt;div id="collapseFiveLeft-311" class="panel-collapse collapse" aria-expanded="false" role="tablist" style="height: 0px;">&lt;div class="panel-body">&lt;div class="text-accordion">&lt;p>這項服務適用於中研院公務政區與對外服務區之自攜電子設備。學術研究區與訪客區不適用。&lt;/p>&lt;/div>&lt;/div>&lt;/div>&lt;/div>&lt;div class="panel panel-default">&lt;div class="panel-heading">&lt;h4 class="panel-title">&lt;a data-toggle="collapse" data-parent="#accordion_oneLeft" href="#collapseFiveLeft-312" aria-expanded="false" class="collapsed">[資安規章] 什麼是自攜電子設備？&lt;/a>&lt;/h4>&lt;/div>&lt;div id="collapseFiveLeft-312" class="panel-collapse collapse" aria-expanded="false" role="tablist" style="height: 0px;">&lt;div class="panel-body">&lt;div class="text-accordion">&lt;p>自攜電子設備是指自己攜帶之桌機、筆電、手機、平板電腦等可上網資訊設備。&lt;/p>&lt;/div>&lt;/div>&lt;/div>&lt;/div>&lt;div class="panel panel-default">&lt;div class="panel-heading">&lt;h4 class="panel-title">&lt;a data-toggle="collapse" data-parent="#accordion_oneLeft" href="#collapseFiveLeft-313" aria-expanded="false" class="collapsed">[資安規章] 什麼是公務政區？&lt;/a>&lt;/h4>&lt;/div>&lt;div id="collapseFiveLeft-313" class="panel-collapse collapse" aria-expanded="false" role="tablist" style="height: 0px;">&lt;div class="panel-body">&lt;div class="text-accordion">&lt;p>公務政區是指中研院辦公室電腦、公務資訊系統伺服器所在之網域。&lt;/p>&lt;/div>&lt;/div>&lt;/div>&lt;/div>&lt;div class="panel panel-default">&lt;div class="panel-heading">&lt;h4 class="panel-title">&lt;a data-toggle="collapse" data-parent="#accordion_oneLeft" href="#collapseFiveLeft-314" aria-expanded="false" class="collapsed">[資安規章] 什麼是對外服務區？&lt;/a>&lt;/h4>&lt;/div>&lt;div id="collapseFiveLeft-314" class="panel-collapse collapse" aria-expanded="false" role="tablist" style="height: 0px;">&lt;div class="panel-body">&lt;div class="text-accordion">&lt;p>對外服務區是指對全院及外界開放之服務系統網區域，在中研院公務政區與對外服務區中使用自攜電子設備時，需遵守相關的安全建議。&lt;/p>&lt;/div>&lt;/div>&lt;/div>&lt;/div>&lt;div class="panel panel-default">&lt;div class="panel-heading">&lt;h4 class="panel-title">&lt;a data-toggle="collapse" data-parent="#accordion_oneLeft" href="#collapseFiveLeft-315" aria-expanded="false" class="collapsed">[資安規章] 什麼是學術研究區？&lt;/a>&lt;/h4>&lt;/div>&lt;div id="collapseFiveLeft-315" class="panel-collapse collapse" aria-expanded="false" role="tablist" style="height: 0px;">&lt;div class="panel-body">&lt;div class="text-accordion">&lt;p>學術研究區是指研究室電腦和伺服器等區域。&lt;/p>&lt;/div>&lt;/div>&lt;/div>&lt;/div>&lt;div class="panel panel-default">&lt;div class="panel-heading">&lt;h4 class="panel-title">&lt;a data-toggle=" ...
# 1.於中研院公務區與對外服務區使用自攜電子設備，建議該區域之網管單位訂定管理措施。
# 2.完成資安防護措施，包括系統、應用程式定期更新、僅安裝所需軟體、安裝防毒及端點防護軟體且維持正常運作、所有應用程式或軟體從官方網站下載安裝。
# 3.避免儲存公務資訊，停止存取公務用網路環境。&lt;/p>&lt;/div>&lt;/div>&lt;/div>&lt;/div>&lt;div class="panel panel-default">&lt;div class="panel-heading">&lt;h4 class="panel-title">&lt;a data-toggle="collapse" data-parent="#accordion_oneLeft" href="#collapseFiveLeft-318" aria-expanded="false" class="collapsed">[不建議使用大陸APP清單] 哪些大陸開發的APP被列入不建議使用清單？&lt;/a>&lt;/h4>&lt;/div>&lt;div id="collapseFiveLeft-318" class="panel-collapse collapse" aria-expanded="false" role="tablist" style="height: 0px;">&lt;div class="panel-body">&lt;div class="text-accordion">&lt;p>抖音(Tiktok) 、微信(WeChat) 、新浪微博 、小影(Viva Video) 、ZOOM會議軟體等。&lt;/p>&lt;/div>&lt;/div>&lt;/div>&lt;/div>&lt;div class="panel panel-default">&lt;div class="panel-heading">&lt;h4 class="panel-title">&lt;a data-toggle="collapse" data-parent="#accordion_oneLeft" href="#collapseFiveLeft-319" aria-expanded="false" class="collapsed">[不建議使用大陸APP清單] 除了大陸開發的APP，還有哪些類型的危險APP不建議使用？&lt;/a>&lt;/h4>&lt;/div>&lt;div id="collapseFiveLeft-319" class="panel-collapse collapse" aria-expanded="false" role="tablist" style="height: 0px;">&lt;div class="panel-body">&lt;div class="text-accordion">&lt;p>工具、通訊類型的危險APP，以及曾發生過資安事件(含疑似案件)的APP及其他有潛在疑慮的APP。&lt;/p>&lt;/div>&lt;/div>&lt;/div>&lt;/div>&lt;div class="panel panel-default">&lt;div class="panel-heading">&lt;h4 class="panel-title">&lt;a data-toggle="collapse" data-parent="#accordion_oneLeft" href="#collapseFiveLeft-320" aria-expanded="false" class="collapsed">[不建議使用大陸APP清單] 哪些曾發生過資安事件的APP不建議使用？&lt;/a>&lt;/h4>&lt;/div>&lt;div id="collapseFiveLeft-320" class="panel-collapse collapse" aria-expanded="false" role="tablist" style="height: 0px;">&lt;div class="panel-body">&lt;div class="text-accordion">&lt;p>建議避免使用曾發生過資安事件(含疑似案件)APP，包括Craigpark Limited 公司旗下所有的APP。&lt;/p>&lt;/div>&lt;/div>&lt;/div>&lt;/div>&lt;div class="panel panel-default">&lt;div class="panel-heading">&lt;h4 class="panel-title">&lt;a data-toggle="collapse" data-parent="#accordion_oneLeft" href="#collapseFiveLeft-321" aria-expanded="false" class="collapsed">[不建議使用大陸APP清單] 哪些其他有潛在疑慮的APP被列入不建議使用清單？&lt;/a>&lt;/h4>&lt;/div>&lt;div id="collapseFiveLeft-321" class="panel-collapse collapse" aria-expanded="false" role="tablist" style="height: 0px;">&lt;div class="panel-body">&lt;div class="text-accordion">&lt;p>其他有潛在疑慮的APP清單包括One Dot Moblie Limited 旗下所有的APP。&lt;/p>&lt;/div>&lt;/div>&lt;/div>&lt;/div>&lt;div class="panel panel-default">&lt;div class="panel-heading">&lt;h4 class="panel-title">&lt;a data-toggle="collapse" data-parent="#accordion_oneLeft" href="#collapseFiveLeft-322" aria-expanded="false" class="collapsed">[大陸廠牌資通訊產品清單] 哪些大陸廠牌資通訊產品包含在清單中？&lt;/a>&lt;/h4>&lt;/div>&lt;div id="collapseFiveLeft-322" class="panel-collapse collapse" aria-expanded="false" role="tablist" style="height: 0px;">&lt;div class="panel-body">&lt;div class="text-accordion">&lt;p>海康威視 (Hikvision)、華為 (Huawei)、大疆 (DJI)、深圳市音?科技有限公司 (INNOTRIK)、廣州文石信息科技有限公司 (BOOX)、深圳市吉祥騰達科技有限公司 (Tenda)。&lt;/p>&lt;/div>&lt;/div>&lt;/div>&lt;/div>&lt;div class="panel panel-default">&lt;div class="panel-heading">&lt;h4 class="panel-title">&lt;a data-toggle="collapse" data-parent="#accordion_oneLeft" href="#collapseFiveLeft-323" aria-expanded="false" class="collapsed">[電子郵件使用安全防護建議] 如何防範電子郵件被駭客攻擊？&lt;/a>&lt;/h4>&lt;/div>&lt;div id="collapseFiveLeft-323" class="panel-collapse collapse" aria-expanded="false" role="tablist" style="height: 0px;">&lt;div class="panel-body">&lt;div class="text-accordion">&lt;p>可以參考中研院提供的資訊服務處電子郵件使用安全防護建議，包括防駭建議、安全性設定、社交工程攻擊防護建議等，進行相關設定，以提升電子郵件使用安全。參考連結：https://its.sinica.edu.tw/posts/155186。&lt;/p>&lt;/div>&lt;/div>&lt;/div>&lt;/div>&lt;div class="panel panel-default">&lt;div class="panel-heading">&lt;h4 class="panel-title">&lt;a data-toggle="collapse" data-parent="#accordion_oneLeft" href="#collapseFiveLeft-324" aria-expanded="false" class="collapsed">[電子郵件使用安全防護建議] 電子郵件的安全設定有哪些？&lt;/a>&lt;/h4>&lt;/div>&lt;div id="collapseFiveLeft-324" class="panel-collapse collapse" aria-expanded="false" role="tablist" style="height: 0px;">&lt;div class="pane ...

# %% [markdown]
# # Reference
#
# - [Creating a synthetic Q&A dataset](https://github.com/openai/openai-cookbook/blob/main/examples/fine-tuned_qa/olympics-2-create-qa.ipynb)
